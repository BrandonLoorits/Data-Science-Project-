# %%
import numpy as np
import pandas as pd

# TODO
data = pd.read_csv("Estonian-2018.csv",sep= ";")
data = data.
data.head()
# Out:
#    Aasta                          Test  Testi ID Sugu  \
# 0   2018  Eesti keel (riigieksam 2018)      3562    M
# 1   2018  Eesti keel (riigieksam 2018)      3562    M
# 2   2018  Eesti keel (riigieksam 2018)      3562    N
# 3   2018  Eesti keel (riigieksam 2018)      3562    N
# 4   2018  Eesti keel (riigieksam 2018)      3562    N
#
#                 Kooli tüüp Õppekeel Soorituskeel             Maakond  \
# 0  põhikool või gümnaasium    eesti   Eesti keel       Harju maakond
# 1  põhikool või gümnaasium    eesti   Eesti keel       Harju maakond
# 2  põhikool või gümnaasium    eesti   Eesti keel  Lääne-Viru maakond
# 3  põhikool või gümnaasium    eesti   Eesti keel       Lääne maakond
# 4  põhikool või gümnaasium    eesti   Eesti keel       Harju maakond
#
#                 Õppeasutus           Õppevorm  ...  Keskmine  Keskmine (%)  \
# 0       Kallavere Keskkool  statsionaarne õpe  ...      39,7          39,7
# ...

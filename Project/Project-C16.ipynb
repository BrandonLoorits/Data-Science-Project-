# %%
#Reading data

# %%
import numpy as np
import pandas as pd

Est2018 = pd.read_csv("Estonian-2018.csv",sep= ";")
Est2018 = Est2018.drop('AUP', axis=1)
Est2018 = Est2018.drop('ÜUP', axis=1)
Est2018 = Est2018.drop("Testi ID",axis=1)
Est2018 = Est2018.drop("Soorituskeel",axis=1)
Est2018 = Est2018.drop("Max võimalik pallide arv",axis=1)

# %%
Est2019 = pd.read_csv("Estonian-2019.csv",sep= ";")
Est2019 = Est2019.drop('AUP', axis=1)
Est2019 = Est2019.drop('ÜUP', axis=1)
Est2019 = Est2019.drop("Testi ID",axis=1)
Est2019 = Est2019.drop("Soorituskeel",axis=1)
Est2019 = Est2019.drop("Max võimalik pallide arv",axis=1)

# %%
Est2020 = pd.read_csv("Estonian-2020.csv",sep= ";")
Est2020 = Est2020.drop('AUP', axis=1)
Est2020 = Est2020.drop('ÜUP', axis=1)
Est2020 = Est2020.drop("Testi ID",axis=1)
Est2020 = Est2020.drop("Soorituskeel",axis=1)
Est2020 = Est2020.drop("Max võimalik pallide arv",axis=1)

# %%
Math2018A = pd.read_csv("Math-advanced-2018.csv",sep= ";")
Math2018A = Math2018A.drop('AUP', axis=1)
Math2018A = Math2018A.drop('ÜUP', axis=1)
Math2018A = Math2018A.drop("Testi ID",axis=1)
Math2018A = Math2018A.drop("Soorituskeel",axis=1)
Math2018A = Math2018A.drop("Max võimalik pallide arv",axis=1)

# %%
Math2019A = pd.read_csv("Math-advanced-2019.csv",sep= ";")
Math2019A = Math2019A.drop('AUP', axis=1)
Math2019A = Math2019A.drop('ÜUP', axis=1)
Math2019A = Math2019A.drop("Testi ID",axis=1)
Math2019A = Math2019A.drop("Soorituskeel",axis=1)
Math2019A = Math2019A.drop("Max võimalik pallide arv",axis=1)

# %%
Math2020A = pd.read_csv("Math-advanced-2020.csv",sep= ";")
Math2020A = Math2020A.drop('AUP', axis=1)
Math2020A = Math2020A.drop('ÜUP', axis=1)
Math2020A = Math2020A.drop("Testi ID",axis=1)
Math2020A = Math2020A.drop("Soorituskeel",axis=1)
Math2020A = Math2020A.drop("Max võimalik pallide arv",axis=1)

# %%
Math2018 = pd.read_csv("Math-simple-2018.csv",sep= ";")
Math2018 = Math2018.drop('AUP', axis=1)
Math2018 = Math2018.drop('ÜUP', axis=1)
Math2018 = Math2018.drop("Testi ID",axis=1)
Math2018 = Math2018.drop("Soorituskeel",axis=1)
Math2018 = Math2018.drop("Max võimalik pallide arv",axis=1)

# %%
Math2019 = pd.read_csv("Math-simple-2019.csv",sep= ";")
Math2019 = Math2019.drop('AUP', axis=1)
Math2019 = Math2019.drop('ÜUP', axis=1)
Math2019 = Math2019.drop("Testi ID",axis=1)
Math2019 = Math2019.drop("Soorituskeel",axis=1)
Math2019 = Math2019.drop("Max võimalik pallide arv",axis=1)

# %%
Math2020 = pd.read_csv("Math-simple-2020.csv",sep= ";")
Math2020 = Math2020.drop('AUP', axis=1)
Math2020 = Math2020.drop('ÜUP', axis=1)
Math2020 = Math2020.drop("Testi ID",axis=1)
Math2020 = Math2020.drop("Soorituskeel",axis=1)
Math2020 = Math2020.drop("Max võimalik pallide arv",axis=1)
Math2020 = Math2020.drop(Math2020.columns[10:],axis=1)

x=Math2020["Õppeasutus"].value_counts()
result=0
for i in x:
    if(i>1):
        result+=1
        
print(result)
# Out:
# 56

# %%
#definition for calculating school total average

dictionary = {"4":835,"3,5":4579}

print(dictionary)
def average(dictionary):
    summary = sum(dictionary.values())
    result = 0
    for i in dictionary:
        #if(type(i)==str):
            #x=i.replace(",",".")
        result += ((dictionary.get(i)/summary)*float(x))
    return result,summary
        
    
print(average(dictionary))
# Out:
# {'4': 835, '3,5': 4579}
# (3.572363569321534, 5414)

# %%
print(Math2020.columns)
duplicates = Math2020[Math2020["Õppeasutus"].duplicated()]
def find(data,school,duplicates):
    result=0
    for i in duplicates[school]:
        dic = {}
        x=data[data[school] == i]
        for num in x:
            print(num)
        #for x in range(len(data)):
            #if(data.iloc[x,6]==i):
                #a=data.iloc[x,9]
                #if(type(a)==str):
                    #a=a.replace(",",".")
                    #a=float(a)
                #dic[a] = data.iloc[x,8]
                #data.drop(x)
        #x=average(dic)
        #print(dic,i)
        #result+=1
        #row.iloc[[2,3,4,7]]="?"
        #row.iloc[8]=x[1]
        #row.iloc[9]=x[0]
    #print(result)
        

        
    
find(Math2020,"Õppeasutus",duplicates)

print(Math2020["Õppeasutus"].value_counts())
# Out:
# Index(['Aasta', 'Test', 'Sugu', 'Kooli tüüp', 'Õppekeel', 'Maakond',
#        'Õppeasutus', 'Õppevorm', 'Sooritajaid', 'Keskmine'],
#       dtype='object')
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Aasta
# Test
# Sugu
# Kooli tüüp
# Õppekeel
# Maakond
# Õppeasutus
# Õppevorm
# Sooritajaid
# Keskmine
# Tallinna Linnamäe Vene Lütseum       4
# Tapa Gümnaasium                      3
# Valga Gümnaasium                     3
# Tallinna Täiskasvanute Gümnaasium    3
# Põlva Gümnaasium                     2
#                                     ..
# Türi Ühisgümnaasium                  1
# Kadrina Keskkool                     1
# Tartu Herbert Masingu Kool           1
# Valga Kaugõppegümnaasium             1
# Paide Täiskasvanute Keskkool         1
# Name: Õppeasutus, Length: 115, dtype: int64

# %%
Parimad_Est2018 = Est2018.sort_values(by="Keskmine",ascending=False).head(10)
Parimad_Est2018.index = np.arange(1, len(Parimad_Est2018) + 1)
print(Parimad_Est2018[["Õppeasutus","Keskmine"]])
# Out:
#                              Õppeasutus Keskmine
# 1                    Tallinna Reaalkool     84,1
# 2             Hugo Treffneri Gümnaasium     83,8
# 3              Tallinna Inglise Kolledž     81,1
# 4            Tallinna Prantsuse Lütseum     80,6
# 5      G. Otsa nim Tallinna Muusikakool     80,2
# 6              Gustav Adolfi Gümnaasium     80,1
# 7                    Tallinna Reaalkool     79,5
# 8                Miina Härma Gümnaasium     79,4
# 9   Pärnu Sütevaka Humanitaargümnaasium     79,1
# 10            Hugo Treffneri Gümnaasium     78,6

# %%
Parimad_Est2019 = Est2019.sort_values(by="Keskmine",ascending=False).head(10)
Parimad_Est2019.index = np.arange(1, len(Parimad_Est2019) + 1)
print(Parimad_Est2019[["Õppeasutus","Keskmine"]])
# Out:
#                              Õppeasutus Keskmine
# 1             Hugo Treffneri Gümnaasium     84,7
# 2            Tallinna Prantsuse Lütseum     84,6
# 3   Pärnu Sütevaka Humanitaargümnaasium     83,7
# 4                    Tallinna Reaalkool     82,6
# 5   Pärnu Sütevaka Humanitaargümnaasium     81,7
# 6             Hugo Treffneri Gümnaasium     81,4
# 7              Gustav Adolfi Gümnaasium       80
# 8           Vanalinna Hariduskolleegium       79
# 9            Tallinna Prantsuse Lütseum     78,8
# 10                   Tallinna Reaalkool     78,7

# %%
Parimad_Est2020 = Est2020.sort_values(by="Keskmine",ascending=False).head(10)
Parimad_Est2020.index = np.arange(1, len(Parimad_Est2020) + 1)
print(Parimad_Est2020[["Õppeasutus","Keskmine"]])
# Out:
#                     Õppeasutus Keskmine
# 1           Tallinna Reaalkool     84,8
# 2   Tallinna Prantsuse Lütseum     83,2
# 3    Hugo Treffneri Gümnaasium     82,1
# 4     Gustav Adolfi Gümnaasium     81,6
# 5   Tallinna Prantsuse Lütseum     80,2
# 6           Tallinna Reaalkool     80,1
# 7     Tallinna Inglise Kolledž     79,5
# 8    Hugo Treffneri Gümnaasium     79,3
# 9            Tallinna 21. Kool     77,9
# 10            Kehra Gümnaasium       76

# %%
Parimad_Math2018A = Math2018A.sort_values(by="Keskmine",ascending=False).head(10)
Parimad_Math2018A.index = np.arange(1, len(Parimad_Math2018A) + 1)
print(Parimad_Math2018A[["Õppeasutus","Keskmine"]])
# Out:
#                              Õppeasutus Keskmine
# 1                   Narva Keeltelütseum     94,5
# 2              Tallinna Inglise Kolledž     93,6
# 3                   Narva Keeltelütseum     91,8
# 4                    Tallinna Reaalkool     88,6
# 5    Tallinna Kesklinna Vene Gümnaasium     88,6
# 6   Pärnu Sütevaka Humanitaargümnaasium     87,8
# 7                    Tallinna Reaalkool     85,2
# 8                       Saue Gümnaasium     83,8
# 9              Gustav Adolfi Gümnaasium     83,1
# 10           Narva Kesklinna Gümnaasium     82,9

# %%
Parimad_Math2018A = Math2018A.sort_values(by="Keskmine",ascending=False).head(10)
Parimad_Math2018A.index = np.arange(1, len(Parimad_Math2018A) + 1)
print(Parimad_Math2018A[["Õppeasutus","Keskmine"]])
# Out:
#                              Õppeasutus Keskmine
# 1                   Narva Keeltelütseum     94,5
# 2              Tallinna Inglise Kolledž     93,6
# 3                   Narva Keeltelütseum     91,8
# 4                    Tallinna Reaalkool     88,6
# 5    Tallinna Kesklinna Vene Gümnaasium     88,6
# 6   Pärnu Sütevaka Humanitaargümnaasium     87,8
# 7                    Tallinna Reaalkool     85,2
# 8                       Saue Gümnaasium     83,8
# 9              Gustav Adolfi Gümnaasium     83,1
# 10           Narva Kesklinna Gümnaasium     82,9

# %%
Parimad_Math2018A = Math2018A.sort_values(by="Keskmine",ascending=False).head(10)
Parimad_Math2018A.index = np.arange(1, len(Parimad_Est2018) + 1)
print(Parimad_Math2018A[["Õppeasutus","Keskmine"]])
# Out:
#                              Õppeasutus Keskmine
# 1                   Narva Keeltelütseum     94,5
# 2              Tallinna Inglise Kolledž     93,6
# 3                   Narva Keeltelütseum     91,8
# 4                    Tallinna Reaalkool     88,6
# 5    Tallinna Kesklinna Vene Gümnaasium     88,6
# 6   Pärnu Sütevaka Humanitaargümnaasium     87,8
# 7                    Tallinna Reaalkool     85,2
# 8                       Saue Gümnaasium     83,8
# 9              Gustav Adolfi Gümnaasium     83,1
# 10           Narva Kesklinna Gümnaasium     82,9

# %%
Parimad_Math2018 = Math2018.sort_values(by="Keskmine",ascending=False).head(10)
Parimad_Math2018.index = np.arange(1, len(Parimad_Math2018) + 1)
print(Parimad_Math2018[["Õppeasutus","Keskmine"]])
# Out:
#                                Õppeasutus Keskmine
# 1   Kohtla-Järve Täiskasvanute Gümnaasium      9,2
# 2                Tartu Kutsehariduskeskus      9,1
# 3                Tallinna Inglise Kolledž     87,1
# 4                    Sakala Eragümnaasium     86,4
# 5               Narva Vanalinna Riigikool     81,7
# 6                     Narva Keeltelütseum     80,4
# 7     Pärnu Sütevaka Humanitaargümnaasium     77,1
# 8                         Saue Gümnaasium     76,2
# 9                Pärnu Koidula Gümnaasium     75,8
# 10               Gustav Adolfi Gümnaasium     75,6

# %%
Parimad_Math2019 = Math2019.sort_values(by="Keskmine",ascending=False).head(10)
Parimad_Math2019.index = np.arange(1, len(Parimad_Math2019) + 1)
print(Parimad_Math2019[["Õppeasutus","Keskmine"]])
# Out:
#                              Õppeasutus Keskmine
# 1           Haapsalu Kutsehariduskeskus      9,8
# 2        Rapla Täiskasvanute Gümnaasium      9,8
# 3              Tallinna Inglise Kolledž     89,2
# 4                   Narva Keeltelütseum     84,9
# 5              Gustav Adolfi Gümnaasium     84,8
# 6                   Narva Keeltelütseum     84,1
# 7              Tallinna Inglise Kolledž     82,9
# 8   Pärnu Sütevaka Humanitaargümnaasium     80,2
# 9           Pärnumaa Kutsehariduskeskus      8,4
# 10             Gustav Adolfi Gümnaasium     78,3

# %%
Parimad_Math2020 = Math2020.sort_values(by="Keskmine",ascending=False).head(10)
Parimad_Math2020.index = np.arange(1, len(Parimad_Math2020) + 1)
print(Parimad_Math2020[["Õppeasutus","Keskmine"]])
# Out:
#                              Õppeasutus Keskmine
# 1                   Narva Keeltelütseum     83,1
# 2              Tallinna Inglise Kolledž     82,6
# 3              Tallinna Inglise Kolledž     80,3
# 4              Viljandi Kutseõppekeskus      8,9
# 5              Tartu Kutsehariduskeskus      8,8
# 6            Tartu Herbert Masingu Kool      8,2
# 7                   Narva Keeltelütseum     77,1
# 8   Pärnu Sütevaka Humanitaargümnaasium     74,9
# 9              Gustav Adolfi Gümnaasium     73,4
# 10                      Saue Gümnaasium     70,2
